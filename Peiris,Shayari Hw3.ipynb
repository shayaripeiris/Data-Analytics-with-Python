# %% [markdown]
# # Homework 3: Walt Disney DataFrame
#
# ### Name: Shayari Peiris
# ### Collaborator: Vishwesh Srinivasan
#
#
# DATA 201A
#
# Fall 2022
#
# Tufts University

# %% [markdown]
# ## Introduction
#
# **Business Context.** For this case, you are working as a data analytics consultant for The Walt Disney Studios, one of the "Big Five" major film studios located in Burbank, CA. The team that recruited you has manually kept track of metrics and attributes associated with each film produced from 1937 to 2016. You, their hired data consultant, have been tasked with the question: **"Which films have been the most lucrative for our studios and how can we use the success of those films as a signal for driving sales forward?"**
#
# You will answer this question by following the tasks provided at the end of this introdcution. The studio has provided you with access to movie content data for each film, gross income per year, and the voice actors data for each film. First, you will load the datasets and join them into a single data structure. Second, you will conduct an analysis of the dataset by following the five tasks provided below.
#
# **Business Problem.** Your task is to **write code in Python to carry out the requested data analysis**.
#
# **Analytical Context.** You are given the data as three separate CSV files, the preferred data format. You haven't been given much instruction on how to use these data sources, but you may want to merge them for easier analysis. As a consultant, your client has requested the following assignments:
#
# 1. Load each dataset and then merge them into a single Pandas DataFrame
# 2. Identify which films generated the highest total gross income for each decade (1930, 1940, 1950, ...)
# 3. Determine which films generated the highest total gross income for each genre
# 4. Taking into account inflation, name the top 10 films that generated the most profit
# 5. Provide the name of each voice actor that played in each of the top movies from Task 4
#
# *Dataset provide by data.world via user kgarrett* <br/>

# %% [markdown]
# ## Overview of the data
#
# The data for this case is contained in the Disney datasets folder provided via Canvas. We will be focusing on the tables that belong to the **Characters, Voice Actors, and Total Gross** categories. Below, you'll find a schema for each of these tables.
#
# Complete documentation for the original data (of which you have only a subset) can be found [here](https://data.world/kgarrett/disney-character-success-00-16/workspace/data-dictionary).
#
# **Disney Characters Table:**
# * **movie_title  (string)**: The title of the film once released by The Walt Disney Studios
# * **release_date (date)**:   The date the film was released in the format YYYY-MM-DD
# * **hero         (string)**: The name of the main protagonist of the film
# * **villian      (string)**: The name of the main antagonist of the film
# * **song         (string)**: The main theme from the film's released soundtrack
#
#
# **Disney Voice Actors Table:**
# * **character   (string)**: The name of any of the given characters featured in the film
# * **voice_actor (string)**: The name of the voice actor playing their associated character
# * **movie       (string)**: The title of the film once released by The Walt Disney Studios
#
# **Disney Movies Total Gross Table:**
# * **movie_title               (string)**: The title of the film once released by The Walt Disney Studios
# * **release_date              (date)**:   The date the film was released in the format YYYY-MM-DD
# * **genre                     (string)**: The genre category of the film
# * **mpaa_rating               (string)**: The parental rating of the film
# * **total_gross               (decimal)**: The amount of income generated by the film by the reported date
# * **inflation_adjusted_gross  (decimal)**: The amount of income generated by the film and adjusted for inflation

# %% [markdown]
# ### Import all necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import math

# %% [markdown]
# ## 1. Loading the Data
#
# (20 points)

# %% [markdown]
# Real-world data is often messy and very dirty. As data practitioners, we often spend our time cleaning and scrubbing data before we even get to the analysis stage. We provide a dataset that is still somewhat dirty but manageable for this assignment. You will be responsible for loading each data source into a single pandas df, though a difficult part of the code has already been written.
#
# **Since our notebook and our datasets folder are located in the same location, we can simply enter the path to read in the dataset. If your notebook and datasets folder are not located in the same folder (also known as repository), then make sure to move them to the same location before running the cell below.**

# %% [markdown]
# Complete the cell below to read in each dataset:

# %%
movie_characters = pd.read_csv('disney-characters.csv')
voice_actors = pd.read_csv('disney-voice-actors.csv')
total_gross = pd.read_csv('disney_movies_total_gross.csv')

# %%
# Run this line before merging your datasets to keep the name of each film clean
movie_characters['movie_title'] = movie_characters['movie_title'].str.replace('\n', '')

# %% [markdown]
# Output the first 15 rows of each dataset using 'df.head()', showing each output in a different cell.

# %%
#Problem 1: outputting first 15 rows for movie_characters
movie_characters.head(15)
# Out:
#                                movie_title        release_date  \
# 0          Snow White and the Seven Dwarfs   December 21, 1937
# 1                                Pinocchio    February 7, 1940
# 2                                 Fantasia   November 13, 1940
# 3                                    Dumbo    October 23, 1941
# 4                                    Bambi     August 13, 1942
# 5                           Saludos Amigos    February 6, 1943
# 6                     The Three Caballeros    February 3, 1945
# 7                          Make Mine Music      April 20, 1946
# 8                       Fun and Fancy Free  September 27, 1947
# 9                              Melody Time        May 27, 1948
# 10  The Adventures of Ichabod and Mr. Toad     October 5, 1949
# 11                              Cinderella   February 15, 1950
# 12                     Alice in Wonderland       July 28, 1951
# 13                               Peter Pan    February 5, 1953
# 14                      Lady and the Tramp       June 22, 1955
#
#                           hero                               villian  \
# 0                   Snow White                            Evil Queen
# 1                    Pinocchio                             Stromboli
# 2                          NaN                             Chernabog
# 3                        Dumbo                            Ringmaster
# 4                        Bambi                                Hunter
# 5                  Donald Duck                                   NaN
# 6                  Donald Duck                                   NaN
# 7                          NaN                                   NaN
# 8                 Mickey Mouse                      Willie the Giant
# 9                          NaN                                   NaN
# 10  Mr. Toad and Ichabod Crane  Mr. Winkie and The Headless Horseman
# 11                  Cinderella                         Lady Tremaine
# 12                       Alice                       Queen of Hearts
# 13                   Peter Pan                          Captain Hook
# 14              Lady and Tramp                             Si and Am
#
#                             song
# 0   Some Day My Prince Will Come
# 1      When You Wish upon a Star
# 2                            NaN
# 3                      Baby Mine
# 4                 Love Is a Song
# 5               Saludos Amigos\n
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                    Little Toot
# 10              The Merrily Song
# 11           Bibbidi-Bobbidi-Boo
# 12           The Unbirthday Song
# 13                  You Can Fly!
# 14                   Bella Notte

# %%
#Problem 1 continued: outputting first 15 rows for voice_actors

voice_actors.head(15)
# Out:
#                 character               voice-actor  \
# 0            Abby Mallard               Joan Cusack
# 1          Abigail Gabble              Monica Evans
# 2                Abis Mal           Jason Alexander
# 3                     Abu              Frank Welker
# 4                Achilles                      None
# 5                  Adella               Sherry Lynn
# 6   Adorabeezle Winterpop                      None
# 7               The Agent              Greg Germann
# 8    Agent Wendy Pleakley            Kevin McDonald
# 9        Ajax the Gorilla                      None
# 10                  Akela               John Abbott
# 11       Al the Alligator         Thurl Ravenscroft
# 12                 Aladar             D. B. Sweeney
# 13                Aladdin  Scott Weinger; Brad Kane
# 14           Alameda Slim               Randy Quaid
#
#                           movie
# 0                Chicken Little
# 1                The Aristocats
# 2           The Return of Jafar
# 3                       Aladdin
# 4   The Hunchback of Notre Dame
# 5            The Little Mermaid
# 6                Wreck-It Ralph
# 7                          Bolt
# 8                 Lilo & Stitch
# 9   Donald Duck and the Gorilla
# 10              The Jungle Book
# 11           Lady and the Tramp
# 12                     Dinosaur
# 13                      Aladdin
# 14            Home on the Range

# %%
#Problem 1 continued: outputting first 15 rows for total_gross

total_gross.head(15)
# Out:
#                         movie_title  release_date      genre MPAA_rating  \
# 0   Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                         Pinocchio   Feb 9, 1940  Adventure           G
# 2                          Fantasia  Nov 13, 1940    Musical           G
# 3                 Song of the South  Nov 12, 1946  Adventure           G
# 4                        Cinderella  Feb 15, 1950      Drama           G
# 5      20,000 Leagues Under the Sea  Dec 23, 1954  Adventure         NaN
# 6                Lady and the Tramp  Jun 22, 1955      Drama           G
# 7                   Sleeping Beauty  Jan 29, 1959      Drama         NaN
# 8                    101 Dalmatians  Jan 25, 1961     Comedy           G
# 9       The Absent Minded Professor  Mar 16, 1961     Comedy         NaN
# 10                 Babes in Toyland  Dec 14, 1961    Musical           G
# 11                      Bon Voyage!  May 17, 1962     Comedy   Not Rated
# 12           The Sword in the Stone  Dec 25, 1963  Adventure         NaN
# 13                  The Jungle Book  Oct 18, 1967    Musical   Not Rated
# 14               Blackbeard's Ghost   Feb 8, 1968     Comedy         NaN
#
#      total_gross inflation_adjusted_gross
# 0   $184,925,485           $5,228,953,251
# 1    $84,300,000           $2,188,229,052
# 2    $83,320,000           $2,187,090,808
# 3    $65,000,000           $1,078,510,579
# 4    $85,000,000             $920,608,730
# 5    $28,200,000             $528,279,994
# 6    $93,600,000           $1,236,035,515
# 7     $9,464,608              $21,505,832
# 8   $153,000,000           $1,362,870,985
# 9    $25,381,407             $310,094,574
# 10   $10,218,316             $124,841,160
# 11    $9,230,769             $109,581,646
# 12   $22,182,353             $153,870,834
# 13  $141,843,000             $789,612,346
# 14   $21,540,050             $138,612,686

# %% [markdown]
# The cell below uses the pandas 'merge' function to merge these individual DataFrames into a single DataFrame.

# %%
# DO NOT EDIT
# The following code merges the datasets into a single pandas df
left_merge = pd.merge(movie_characters, total_gross, on='movie_title')
# We rename the 'movie_title' column to 'movies' to join the datasets
left_merge = left_merge.rename(columns={"movie_title": "movie"})
disney_data = pd.merge(left_merge, voice_actors, on='movie')
# Generate a unique film ID with random seed for each film
# This seeding approach has been improved in 2021
np.random.seed(2021) 
ID_range = np.arange(100000, 900000)
IDs = {m: np.random.choice(ID_range, 1, replace=False)[0] for m in set(disney_data.movie)}
# Assign the unique ID to each film
disney_data['film_id'] = ''
for film, ID in IDs.items():
    disney_data.loc[disney_data['movie'] == film,'film_id'] = str(ID)
# We observe multiple rows of same film with different characters below
disney_data.head()
# Out:
#                              movie     release_date_x        hero     villian  \
# 0  Snow White and the Seven Dwarfs  December 21, 1937  Snow White  Evil Queen
# 1  Snow White and the Seven Dwarfs  December 21, 1937  Snow White  Evil Queen
# 2  Snow White and the Seven Dwarfs  December 21, 1937  Snow White  Evil Queen
# 3  Snow White and the Seven Dwarfs  December 21, 1937  Snow White  Evil Queen
# 4  Snow White and the Seven Dwarfs  December 21, 1937  Snow White  Evil Queen
#
#                            song release_date_y    genre MPAA_rating  \
# 0  Some Day My Prince Will Come   Dec 21, 1937  Musical           G
# 1  Some Day My Prince Will Come   Dec 21, 1937  Musical           G
# 2  Some Day My Prince Will Come   Dec 21, 1937  Musical           G
# 3  Some Day My Prince Will Come   Dec 21, 1937  Musical           G
# 4  Some Day My Prince Will Come   Dec 21, 1937  Musical           G
#
#     total_gross inflation_adjusted_gross character     voice-actor film_id
# 0  $184,925,485           $5,228,953,251   Bashful  Scotty Mattraw  482267
# 1  $184,925,485           $5,228,953,251       Doc      Roy Atwell  482267
# 2  $184,925,485           $5,228,953,251     Dopey   Eddie Collins  482267
# 3  $184,925,485           $5,228,953,251    Grumpy    Pinto Colvig  482267
# 4  $184,925,485           $5,228,953,251     Happy     Otis Harlan  482267

# %% [markdown]
# You can run the cell below to see the unique IDs we generated for each film:

# %%
# DO NOT EDIT
IDs
# Out:
# {'The Rescuers': 219262,
#  'Frozen': 550486,
#  'Beauty and the Beast': 130897,
#  'Big Hero 6': 329503,
#  'Brother Bear': 693653,
#  'Sleeping Beauty': 836088,
#  'Treasure Planet': 410813,
#  'The Hunchback of Notre Dame': 209015,
#  'Wreck-It Ralph': 779135,
#  'Atlantis: The Lost Empire': 806340,
#  'Mulan': 796593,
#  'The Princess and the Frog': 407506,
#  'Cinderella': 736543,
#  'Meet the Robinsons': 694537,
#  'Moana': 339918,
#  'The Sword in the Stone': 364740,
#  'The Lion King': 882484,
#  'Lady and the Tramp': 821764,
#  'Oliver & Company': 703293,
#  'The Fox and the Hound': 683327,
#  'The Black Cauldron': 630281,
#  'The Rescuers Down Under': 892987,
#  'Zootopia': 251627,
#  'Alice in Wonderland': 787062,
#  'Lilo & Stitch': 645858,
#  'Snow White and the Seven Dwarfs': 482267,
#  'Tarzan': 464805,
#  'The Jungle Book': 576980,
#  'Home on the Range': 149306,
#  'The Great Mouse Detective': 320542,
#  'Hercules': 230805,
#  "The Emperor's New Groove": 701647,
#  'Fantasia': 149036,
#  'The Little Mermaid': 120461,
#  'Aladdin': 335712,
#  'Pocahontas': 390797,
#  'Bolt': 401532,
#  'Chicken Little': 202056,
#  'Pinocchio': 484637,
#  'Dinosaur': 746864,
#  'Tangled': 407513,
#  'The Aristocats': 221817}

# %% [markdown]
# Run the following cell to perform some string data cleaning on our Disney dataset:

# %%
# DO NOT EDIT

# Remove currency symbol from all values in the columns we want as numeric
disney_data["total_gross"] = disney_data["total_gross"].str[1:]
disney_data["inflation_adjusted_gross"] = disney_data["inflation_adjusted_gross"].str[1:]

# Remove all commas from strings
disney_data['total_gross'] = disney_data['total_gross'].str.replace(',', '')
disney_data['inflation_adjusted_gross'] = disney_data['inflation_adjusted_gross'].str.replace(',', '')

# Convert to correct dtype to avoid future bugs
disney_data["total_gross"] = pd.to_numeric(disney_data["total_gross"])
disney_data["inflation_adjusted_gross"] = pd.to_numeric(disney_data["inflation_adjusted_gross"])

# %%
# DO NOT EDIT

disney_data.dtypes
# Out:
# movie                       object
# release_date_x              object
# hero                        object
# villian                     object
# song                        object
# release_date_y              object
# genre                       object
# MPAA_rating                 object
# total_gross                  int64
# inflation_adjusted_gross     int64
# character                   object
# voice-actor                 object
# film_id                     object
# dtype: object

# %% [markdown]
# ## 2. Film with highest total gross income for each decade (1930, 1940, 1950, ...)
#
# (20 points)

# %% [markdown]
# To analyze a dataset using dates, we need to convert the dtype of our column 'release_date_x' to the 'Datetime' format in pandas.
# We can use ['to_datetime'](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html) to accomplish this goal by converting our column 'release_date_x' to datetime. It is currently type 'object' which is an ambiguous dtype used for strings or mixed values in pandas.
#
# Run the cell below to see the current dtype of the column.

# %%
disney_data.release_date_x
# Out:
# 0      December 21, 1937
# 1      December 21, 1937
# 2      December 21, 1937
# 3      December 21, 1937
# 4      December 21, 1937
#              ...
# 595    November 23, 2016
# 596    November 23, 2016
# 597    November 23, 2016
# 598    November 23, 2016
# 599    November 23, 2016
# Name: release_date_x, Length: 600, dtype: object

# %% [markdown]
# Run the following cell to convert our release dates to the Datetime dtype:

# %%
disney_data['release_date_x'] = pd.to_datetime(disney_data['release_date_x'])

# %% [markdown]
# Now, the dtype of our column 'release_date_x' should say 'datetime64[ns]' as seen below. You can try the 'to_datetime' function with different formats by reading the pandas documentation linked to in the previous cell. We will use this column to group our dataset by release date.

# %%
disney_data.release_date_x
# Out:
# 0     1937-12-21
# 1     1937-12-21
# 2     1937-12-21
# 3     1937-12-21
# 4     1937-12-21
#          ...
# 595   2016-11-23
# 596   2016-11-23
# 597   2016-11-23
# 598   2016-11-23
# 599   2016-11-23
# Name: release_date_x, Length: 600, dtype: datetime64[ns]

# %% [markdown]
# Now, we can use the 'groupby' function to group our dataset by decade and find the film with the highest gross income for each decade.
#
# 1. Group films by 'film_id' and use '.first()' to ensure we are only looking at unique films.
# 2. Sort values by year and, most importantly, total gross (non-adjusted).
# 3. Determine the highest grossing film for each decade available.

# %%
# Step 1
# TO DO:
# Group the films by ID using the first appearance
# in the grouping. Store this value in a variable
# called 'by_id'. You will run into errors later
# in the code if you do not use this variable
# name EXACTLY as written.

# Step 2
# TO DO:
# Sort the values by year and then sort by 
# total gross (non-adjusted) value. Store
# this value in a variable called 'by_release_date'.
# Again, follow the exact variable name provided.

# STEP 3
# TO DO:
# To find the highest grossing film, you can do so manually by looking at the values 
# for each film for each decade and record the answers below or use pandas to accomplish 
# this task using Datetime. For the second (and preferred) option, you may need to look up 
# how to set a pandas index with datetime values.

# %%
#Problem 2
#Step 1: grouping films by id using the first appearance and storing in by_id

by_id = disney_data.groupby(['film_id']).first()
by_id
# Out:
#                                    movie release_date_x  \
# film_id
# 120461                The Little Mermaid     1989-11-17
# 130897              Beauty and the Beast     1991-11-22
# 149036                          Fantasia     1940-11-13
# 149306                 Home on the Range     2004-04-02
# 202056                    Chicken Little     2005-11-04
# 209015       The Hunchback of Notre Dame     1996-06-21
# 219262                      The Rescuers     1977-06-22
# 221817                    The Aristocats     1970-12-24
# 230805                          Hercules     1997-06-27
# 251627                          Zootopia     2016-03-04
# 320542         The Great Mouse Detective     1986-07-02
# 329503                        Big Hero 6     2014-11-07
# 335712                           Aladdin     1992-11-25
# 339918                             Moana     2016-11-23
# 364740            The Sword in the Stone     1963-12-25
# 390797                        Pocahontas     1995-06-23
# 401532                              Bolt     2008-11-21
# 407506         The Princess and the Frog     2009-12-11
# 407513                           Tangled     2010-11-24
# 410813                   Treasure Planet     2002-11-27
# 464805                            Tarzan     1999-06-18
# 482267   Snow White and the Seven Dwarfs     1937-12-21
# 484637                         Pinocchio     1940-02-07
# 550486                            Frozen     2013-11-27
# 576980                   The Jungle Book     1967-10-18
# 630281                The Black Cauldron     1985-07-24
# 645858                     Lilo & Stitch     2002-06-21
# 683327             The Fox and the Hound     1981-07-10
# 693653                      Brother Bear     2003-11-01
# 694537                Meet the Robinsons     2007-03-30
# 701647          The Emperor's New Groove     2000-12-15
# 703293                  Oliver & Company     1988-11-18
# 736543                        Cinderella     1950-02-15
# 746864                          Dinosaur     2000-05-19
# 779135                    Wreck-It Ralph     2012-11-02
# 787062               Alice in Wonderland     1951-07-28
# 796593                             Mulan     1998-06-19
# 806340         Atlantis: The Lost Empire     2001-06-15
# 821764                Lady and the Tramp     1955-06-22
# 836088                   Sleeping Beauty     1959-01-29
# 882484                     The Lion King     1994-06-24
# 892987           The Rescuers Down Under     1990-11-16
#
#                             hero              villian  \
# film_id
# 120461                     Ariel               Ursula
# 130897                     Belle               Gaston
# 149036                      None            Chernabog
# 149306                    Maggie         Alameda Slim
# 202056                 Ace Cluck            Foxy Loxy
# 209015                 Quasimodo        Claude Frollo
# 219262   Bernard and Miss Bianca        Madame Medusa
# 221817        Thomas and Duchess      Edgar Balthazar
# 230805                  Hercules                Hades
# 251627                Judy Hopps                 None
# 320542                     Basil    Professor Ratigan
# 329503               Hiro Hamada  Professor Callaghan
# 335712                   Aladdin                Jafar
# 339918                     Moana                 None
# 364740                    Arthur            Madam Mim
# 390797                Pocahontas   Governor Ratcliffe
# 401532                      Bolt           Dr. Calico
# 407506                     Tiana         Dr. Facilier
# 407513                  Rapunzel        Mother Gothel
# 410813               Jim Hawkins          John Silver
# 464805                    Tarzan              Clayton
# 482267                Snow White           Evil Queen
# 484637                 Pinocchio            Stromboli
# 550486                      Elsa          Prince Hans
# 576980                    Mowgli   Kaa and Shere Khan
# 630281                     Taran          Horned King
# 645858           Lilo and Stitch                 None
# 683327            Tod and Copper           Amos Slade
# 693653                     Kenai               Denahi
# 694537                     Lewis                Doris
# 701647                     Kuzco                 Yzma
# 703293                    Oliver                Sykes
# 736543                Cinderella        Lady Tremaine
# 746864                    Aladar                 Kron
# 779135                     Ralph                Turbo
# 787062                     Alice      Queen of Hearts
# 796593                     Mulan              Shan Yu
# 806340               Milo Thatch     Commander Rourke
# 821764            Lady and Tramp            Si and Am
# 836088                    Aurora           Maleficent
# 882484                     Simba                 Scar
# 892987   Bernard and Miss Bianca  Percival C. McLeach
#
#                                        song release_date_y      genre  \
# film_id
# 120461                        Under the Sea   Nov 15, 1989  Adventure
# 130897                         Be Our Guest   Nov 13, 1991    Musical
# 149036                                 None   Nov 13, 1940    Musical
# 149306                                 None    Apr 2, 2004     Comedy
# 202056                                 None    Nov 4, 2005  Adventure
# 209015                God Help the Outcasts   Jun 21, 1996  Adventure
# 219262                          The Journey   Jun 22, 1977  Adventure
# 221817          Ev'rybody Wants to Be a Cat   Apr 24, 1970    Musical
# 230805                      Go the Distance   Jun 13, 1997  Adventure
# 251627                       Try Everything    Mar 4, 2016  Adventure
# 320542   The World's Greatest Criminal Mind    Jul 2, 1986  Adventure
# 329503                            Immortals    Nov 7, 2014  Adventure
# 335712                    A Whole New World   Nov 11, 1992     Comedy
# 339918                    How Far I'll Go\n   Nov 23, 2016  Adventure
# 364740                    Higitus Figitus\n   Dec 25, 1963  Adventure
# 390797                   Colors of the Wind   Jun 10, 1995  Adventure
# 401532                 I Thought I Lost You   Nov 21, 2008     Comedy
# 407506                         Almost There   Nov 25, 2009  Adventure
# 407513                      I See the Light   Nov 24, 2010  Adventure
# 410813                     I'm Still Here\n   Nov 27, 2002  Adventure
# 464805                You'll Be in My Heart   Jun 16, 1999  Adventure
# 482267         Some Day My Prince Will Come   Dec 21, 1937    Musical
# 484637            When You Wish upon a Star    Feb 9, 1940  Adventure
# 550486                          Let It Go\n   Nov 22, 2013  Adventure
# 576980               The Bare Necessities\n   Oct 18, 1967    Musical
# 630281                                 None   Jul 24, 1985  Adventure
# 645858                    He Mele No Lilo\n   Jun 21, 2002  Adventure
# 683327                      Best of Friends   Jul 10, 1981     Comedy
# 693653                 Look Through My Eyes   Oct 24, 2003  Adventure
# 694537                       Little Wonders   Mar 30, 2007  Adventure
# 701647             My Funny Friend and Me\n   Dec 15, 2000  Adventure
# 703293    Once Upon a Time in New York City   Nov 18, 1988  Adventure
# 736543                  Bibbidi-Bobbidi-Boo   Feb 15, 1950      Drama
# 746864                                 None   May 19, 2000  Adventure
# 779135                           Sugar Rush    Nov 2, 2012  Adventure
# 787062                  The Unbirthday Song    Mar 5, 2010  Adventure
# 796593         I'll Make a Man Out of You\n   Jun 19, 1998  Adventure
# 806340            Where the Dream Takes You    Jun 8, 2001  Adventure
# 821764                          Bella Notte   Jun 22, 1955      Drama
# 836088                    Once Upon a Dream   Jan 29, 1959      Drama
# 882484                       Circle of Life   Jun 15, 1994  Adventure
# 892987                                   \n   Nov 16, 1990  Adventure
#
#         MPAA_rating  total_gross  inflation_adjusted_gross  \
# film_id
# 120461            G    111543479                 223726012
# 130897            G    218951625                 363017667
# 149036            G     83320000                2187090808
# 149306           PG     50026353                  67910166
# 202056            G    135386665                 177954661
# 209015            G    100138851                 190988799
# 219262         None     48775599                 159743914
# 221817            G     55675257                 255161499
# 230805            G     99112101                 182029412
# 251627           PG    341268248                 341268248
# 320542         None     23605534                  53637367
# 329503           PG    222527828                 229249222
# 335712            G    217350219                 441969178
# 339918           PG    246082029                 246082029
# 364740         None     22182353                 153870834
# 390797            G    141579773                 274370957
# 401532           PG    114053759                 133702498
# 407506            G    104400899                 116316457
# 407513           PG    200821936                 214388548
# 410813           PG     38120554                  55189145
# 464805            G    171091819                 283900254
# 482267            G    184925485                5228953251
# 484637            G     84300000                2188229052
# 550486           PG    400738009                 414997174
# 576980    Not Rated    141843000                 789612346
# 630281         None     21288692                  50553142
# 645858           PG    145771527                 211506702
# 683327         None     43899231                 133118889
# 693653            G     85336277                 119218333
# 694537            G     97822171                 119860589
# 701647            G     89296573                 136789252
# 703293            G     49576671                 102254492
# 736543            G     85000000                 920608730
# 746864           PG    137748063                 215438985
# 779135           PG    189412677                 200354959
# 787062           PG    334191110                 357063499
# 796593            G    120620254                 216807832
# 806340           PG     84052762                 125188122
# 821764            G     93600000                1236035515
# 836088         None      9464608                  21505832
# 882484            G    422780140                 761640898
# 892987            G     27931461                  55796728
#
#                                character          voice-actor
# film_id
# 120461                            Adella          Sherry Lynn
# 130897                           Armoire       Jo Anne Worley
# 149036                     Ben Ali Gator         Jim Cummings
# 149306                      Alameda Slim          Randy Quaid
# 202056                      Abby Mallard          Joan Cusack
# 209015                          Achilles                 None
# 219262                           Bernard         Bob Newheart
# 221817                    Abigail Gabble         Monica Evans
# 230805                           Alcmene       Barbara Barrie
# 251627   Assistant Mayor Dawn Bellwether          Jenny Slate
# 320542                       Bartholomew        Barrie Ingham
# 329503                    Tadashi Hamada        Daniel Henney
# 335712                               Abu         Frank Welker
# 339918                       Gramma Tala         Rachel House
# 364740                        Archimedes      Junius Matthews
# 390797                               Ben       Billy Connolly
# 401532                         The Agent         Greg Germann
# 407506                   Buford the Cook       Michael Colyar
# 407513                       Flynn Rider         Zachary Levi
# 410813                            B.E.N.         Martin Short
# 464805              Archimedes Q. Porter      Nigel Hawthorne
# 482267                           Bashful       Scotty Mattraw
# 484637                        Blue Fairy       Evelyn Venable
# 550486                              Anna         Kristen Bell
# 576980                             Akela          John Abbott
# 630281                           Creeper       Phil Fondacaro
# 645858              Agent Wendy Pleakley       Kevin McDonald
# 683327                        Amos Slade       Jack Albertson
# 693653                            Denahi          Jason Raize
# 694537                    Bowler Hat Guy  Stephen J. Anderson
# 701647                Bucky the Squirrel           Bob Bergen
# 703293                            DeSoto       Carl Weintraub
# 736543                Anastasia Tremaine        Lucille Bliss
# 746864                            Aladar        D. B. Sweeney
# 779135             Adorabeezle Winterpop                 None
# 787062                             Alice     Kathryn Beaumont
# 796593                            Chi-Fu           James Hong
# 806340                    Audrey Ramirez  Jacqueline Obradors
# 821764                  Al the Alligator    Thurl Ravenscroft
# 836088                            Aurora           Mary Costa
# 882484                            Banzai         Cheech Marin
# 892987                              Cody            Adam Ryen

# %%
#Problem 2 continued
#Step 2: grouping films by release date and total_gross and storing in by_release_date

by_release_date = by_id.sort_values(by=['release_date_x', 'total_gross'])
by_release_date
# Out:
#                                    movie release_date_x  \
# film_id
# 482267   Snow White and the Seven Dwarfs     1937-12-21
# 484637                         Pinocchio     1940-02-07
# 149036                          Fantasia     1940-11-13
# 736543                        Cinderella     1950-02-15
# 787062               Alice in Wonderland     1951-07-28
# 821764                Lady and the Tramp     1955-06-22
# 836088                   Sleeping Beauty     1959-01-29
# 364740            The Sword in the Stone     1963-12-25
# 576980                   The Jungle Book     1967-10-18
# 221817                    The Aristocats     1970-12-24
# 219262                      The Rescuers     1977-06-22
# 683327             The Fox and the Hound     1981-07-10
# 630281                The Black Cauldron     1985-07-24
# 320542         The Great Mouse Detective     1986-07-02
# 703293                  Oliver & Company     1988-11-18
# 120461                The Little Mermaid     1989-11-17
# 892987           The Rescuers Down Under     1990-11-16
# 130897              Beauty and the Beast     1991-11-22
# 335712                           Aladdin     1992-11-25
# 882484                     The Lion King     1994-06-24
# 390797                        Pocahontas     1995-06-23
# 209015       The Hunchback of Notre Dame     1996-06-21
# 230805                          Hercules     1997-06-27
# 796593                             Mulan     1998-06-19
# 464805                            Tarzan     1999-06-18
# 746864                          Dinosaur     2000-05-19
# 701647          The Emperor's New Groove     2000-12-15
# 806340         Atlantis: The Lost Empire     2001-06-15
# 645858                     Lilo & Stitch     2002-06-21
# 410813                   Treasure Planet     2002-11-27
# 693653                      Brother Bear     2003-11-01
# 149306                 Home on the Range     2004-04-02
# 202056                    Chicken Little     2005-11-04
# 694537                Meet the Robinsons     2007-03-30
# 401532                              Bolt     2008-11-21
# 407506         The Princess and the Frog     2009-12-11
# 407513                           Tangled     2010-11-24
# 779135                    Wreck-It Ralph     2012-11-02
# 550486                            Frozen     2013-11-27
# 329503                        Big Hero 6     2014-11-07
# 251627                          Zootopia     2016-03-04
# 339918                             Moana     2016-11-23
#
#                             hero              villian  \
# film_id
# 482267                Snow White           Evil Queen
# 484637                 Pinocchio            Stromboli
# 149036                      None            Chernabog
# 736543                Cinderella        Lady Tremaine
# 787062                     Alice      Queen of Hearts
# 821764            Lady and Tramp            Si and Am
# 836088                    Aurora           Maleficent
# 364740                    Arthur            Madam Mim
# 576980                    Mowgli   Kaa and Shere Khan
# 221817        Thomas and Duchess      Edgar Balthazar
# 219262   Bernard and Miss Bianca        Madame Medusa
# 683327            Tod and Copper           Amos Slade
# 630281                     Taran          Horned King
# 320542                     Basil    Professor Ratigan
# 703293                    Oliver                Sykes
# 120461                     Ariel               Ursula
# 892987   Bernard and Miss Bianca  Percival C. McLeach
# 130897                     Belle               Gaston
# 335712                   Aladdin                Jafar
# 882484                     Simba                 Scar
# 390797                Pocahontas   Governor Ratcliffe
# 209015                 Quasimodo        Claude Frollo
# 230805                  Hercules                Hades
# 796593                     Mulan              Shan Yu
# 464805                    Tarzan              Clayton
# 746864                    Aladar                 Kron
# 701647                     Kuzco                 Yzma
# 806340               Milo Thatch     Commander Rourke
# 645858           Lilo and Stitch                 None
# 410813               Jim Hawkins          John Silver
# 693653                     Kenai               Denahi
# 149306                    Maggie         Alameda Slim
# 202056                 Ace Cluck            Foxy Loxy
# 694537                     Lewis                Doris
# 401532                      Bolt           Dr. Calico
# 407506                     Tiana         Dr. Facilier
# 407513                  Rapunzel        Mother Gothel
# 779135                     Ralph                Turbo
# 550486                      Elsa          Prince Hans
# 329503               Hiro Hamada  Professor Callaghan
# 251627                Judy Hopps                 None
# 339918                     Moana                 None
#
#                                        song release_date_y      genre  \
# film_id
# 482267         Some Day My Prince Will Come   Dec 21, 1937    Musical
# 484637            When You Wish upon a Star    Feb 9, 1940  Adventure
# 149036                                 None   Nov 13, 1940    Musical
# 736543                  Bibbidi-Bobbidi-Boo   Feb 15, 1950      Drama
# 787062                  The Unbirthday Song    Mar 5, 2010  Adventure
# 821764                          Bella Notte   Jun 22, 1955      Drama
# 836088                    Once Upon a Dream   Jan 29, 1959      Drama
# 364740                    Higitus Figitus\n   Dec 25, 1963  Adventure
# 576980               The Bare Necessities\n   Oct 18, 1967    Musical
# 221817          Ev'rybody Wants to Be a Cat   Apr 24, 1970    Musical
# 219262                          The Journey   Jun 22, 1977  Adventure
# 683327                      Best of Friends   Jul 10, 1981     Comedy
# 630281                                 None   Jul 24, 1985  Adventure
# 320542   The World's Greatest Criminal Mind    Jul 2, 1986  Adventure
# 703293    Once Upon a Time in New York City   Nov 18, 1988  Adventure
# 120461                        Under the Sea   Nov 15, 1989  Adventure
# 892987                                   \n   Nov 16, 1990  Adventure
# 130897                         Be Our Guest   Nov 13, 1991    Musical
# 335712                    A Whole New World   Nov 11, 1992     Comedy
# 882484                       Circle of Life   Jun 15, 1994  Adventure
# 390797                   Colors of the Wind   Jun 10, 1995  Adventure
# 209015                God Help the Outcasts   Jun 21, 1996  Adventure
# 230805                      Go the Distance   Jun 13, 1997  Adventure
# 796593         I'll Make a Man Out of You\n   Jun 19, 1998  Adventure
# 464805                You'll Be in My Heart   Jun 16, 1999  Adventure
# 746864                                 None   May 19, 2000  Adventure
# 701647             My Funny Friend and Me\n   Dec 15, 2000  Adventure
# 806340            Where the Dream Takes You    Jun 8, 2001  Adventure
# 645858                    He Mele No Lilo\n   Jun 21, 2002  Adventure
# 410813                     I'm Still Here\n   Nov 27, 2002  Adventure
# 693653                 Look Through My Eyes   Oct 24, 2003  Adventure
# 149306                                 None    Apr 2, 2004     Comedy
# 202056                                 None    Nov 4, 2005  Adventure
# 694537                       Little Wonders   Mar 30, 2007  Adventure
# 401532                 I Thought I Lost You   Nov 21, 2008     Comedy
# 407506                         Almost There   Nov 25, 2009  Adventure
# 407513                      I See the Light   Nov 24, 2010  Adventure
# 779135                           Sugar Rush    Nov 2, 2012  Adventure
# 550486                          Let It Go\n   Nov 22, 2013  Adventure
# 329503                            Immortals    Nov 7, 2014  Adventure
# 251627                       Try Everything    Mar 4, 2016  Adventure
# 339918                    How Far I'll Go\n   Nov 23, 2016  Adventure
#
#         MPAA_rating  total_gross  inflation_adjusted_gross  \
# film_id
# 482267            G    184925485                5228953251
# 484637            G     84300000                2188229052
# 149036            G     83320000                2187090808
# 736543            G     85000000                 920608730
# 787062           PG    334191110                 357063499
# 821764            G     93600000                1236035515
# 836088         None      9464608                  21505832
# 364740         None     22182353                 153870834
# 576980    Not Rated    141843000                 789612346
# 221817            G     55675257                 255161499
# 219262         None     48775599                 159743914
# 683327         None     43899231                 133118889
# 630281         None     21288692                  50553142
# 320542         None     23605534                  53637367
# 703293            G     49576671                 102254492
# 120461            G    111543479                 223726012
# 892987            G     27931461                  55796728
# 130897            G    218951625                 363017667
# 335712            G    217350219                 441969178
# 882484            G    422780140                 761640898
# 390797            G    141579773                 274370957
# 209015            G    100138851                 190988799
# 230805            G     99112101                 182029412
# 796593            G    120620254                 216807832
# 464805            G    171091819                 283900254
# 746864           PG    137748063                 215438985
# 701647            G     89296573                 136789252
# 806340           PG     84052762                 125188122
# 645858           PG    145771527                 211506702
# 410813           PG     38120554                  55189145
# 693653            G     85336277                 119218333
# 149306           PG     50026353                  67910166
# 202056            G    135386665                 177954661
# 694537            G     97822171                 119860589
# 401532           PG    114053759                 133702498
# 407506            G    104400899                 116316457
# 407513           PG    200821936                 214388548
# 779135           PG    189412677                 200354959
# 550486           PG    400738009                 414997174
# 329503           PG    222527828                 229249222
# 251627           PG    341268248                 341268248
# 339918           PG    246082029                 246082029
#
#                                character          voice-actor
# film_id
# 482267                           Bashful       Scotty Mattraw
# 484637                        Blue Fairy       Evelyn Venable
# 149036                     Ben Ali Gator         Jim Cummings
# 736543                Anastasia Tremaine        Lucille Bliss
# 787062                             Alice     Kathryn Beaumont
# 821764                  Al the Alligator    Thurl Ravenscroft
# 836088                            Aurora           Mary Costa
# 364740                        Archimedes      Junius Matthews
# 576980                             Akela          John Abbott
# 221817                    Abigail Gabble         Monica Evans
# 219262                           Bernard         Bob Newheart
# 683327                        Amos Slade       Jack Albertson
# 630281                           Creeper       Phil Fondacaro
# 320542                       Bartholomew        Barrie Ingham
# 703293                            DeSoto       Carl Weintraub
# 120461                            Adella          Sherry Lynn
# 892987                              Cody            Adam Ryen
# 130897                           Armoire       Jo Anne Worley
# 335712                               Abu         Frank Welker
# 882484                            Banzai         Cheech Marin
# 390797                               Ben       Billy Connolly
# 209015                          Achilles                 None
# 230805                           Alcmene       Barbara Barrie
# 796593                            Chi-Fu           James Hong
# 464805              Archimedes Q. Porter      Nigel Hawthorne
# 746864                            Aladar        D. B. Sweeney
# 701647                Bucky the Squirrel           Bob Bergen
# 806340                    Audrey Ramirez  Jacqueline Obradors
# 645858              Agent Wendy Pleakley       Kevin McDonald
# 410813                            B.E.N.         Martin Short
# 693653                            Denahi          Jason Raize
# 149306                      Alameda Slim          Randy Quaid
# 202056                      Abby Mallard          Joan Cusack
# 694537                    Bowler Hat Guy  Stephen J. Anderson
# 401532                         The Agent         Greg Germann
# 407506                   Buford the Cook       Michael Colyar
# 407513                       Flynn Rider         Zachary Levi
# 779135             Adorabeezle Winterpop                 None
# 550486                              Anna         Kristen Bell
# 329503                    Tadashi Hamada        Daniel Henney
# 251627   Assistant Mayor Dawn Bellwether          Jenny Slate
# 339918                       Gramma Tala         Rachel House

# %%
#Problem 2 continued
#Step 3: creating by_release_date_index by setting index as 'release_date_x'; creating decade_highest_gross and 
#converting index to decades and then taxing the max total gross for each decade

by_release_date_index = by_release_date.set_index('release_date_x')
decade_highest_gross = by_release_date_index.groupby((by_release_date_index.index.year//10)*10)['total_gross'].max()
decade_highest_gross
# Out:
# release_date_x
# 1930    184925485
# 1940     84300000
# 1950    334191110
# 1960    141843000
# 1970     55675257
# 1980    111543479
# 1990    422780140
# 2000    145771527
# 2010    400738009
# Name: total_gross, dtype: int64

# %%
by_release_date_index
# Out:
#                                           movie                     hero  \
# release_date_x
# 1937-12-21      Snow White and the Seven Dwarfs               Snow White
# 1940-02-07                            Pinocchio                Pinocchio
# 1940-11-13                             Fantasia                     None
# 1950-02-15                           Cinderella               Cinderella
# 1951-07-28                  Alice in Wonderland                    Alice
# 1955-06-22                   Lady and the Tramp           Lady and Tramp
# 1959-01-29                      Sleeping Beauty                   Aurora
# 1963-12-25               The Sword in the Stone                   Arthur
# 1967-10-18                      The Jungle Book                   Mowgli
# 1970-12-24                       The Aristocats       Thomas and Duchess
# 1977-06-22                         The Rescuers  Bernard and Miss Bianca
# 1981-07-10                The Fox and the Hound           Tod and Copper
# 1985-07-24                   The Black Cauldron                    Taran
# 1986-07-02            The Great Mouse Detective                    Basil
# 1988-11-18                     Oliver & Company                   Oliver
# 1989-11-17                   The Little Mermaid                    Ariel
# 1990-11-16              The Rescuers Down Under  Bernard and Miss Bianca
# 1991-11-22                 Beauty and the Beast                    Belle
# 1992-11-25                              Aladdin                  Aladdin
# 1994-06-24                        The Lion King                    Simba
# 1995-06-23                           Pocahontas               Pocahontas
# 1996-06-21          The Hunchback of Notre Dame                Quasimodo
# 1997-06-27                             Hercules                 Hercules
# 1998-06-19                                Mulan                    Mulan
# 1999-06-18                               Tarzan                   Tarzan
# 2000-05-19                             Dinosaur                   Aladar
# 2000-12-15             The Emperor's New Groove                    Kuzco
# 2001-06-15            Atlantis: The Lost Empire              Milo Thatch
# 2002-06-21                        Lilo & Stitch          Lilo and Stitch
# 2002-11-27                      Treasure Planet              Jim Hawkins
# 2003-11-01                         Brother Bear                    Kenai
# 2004-04-02                    Home on the Range                   Maggie
# 2005-11-04                       Chicken Little                Ace Cluck
# 2007-03-30                   Meet the Robinsons                    Lewis
# 2008-11-21                                 Bolt                     Bolt
# 2009-12-11            The Princess and the Frog                    Tiana
# 2010-11-24                              Tangled                 Rapunzel
# 2012-11-02                       Wreck-It Ralph                    Ralph
# 2013-11-27                               Frozen                     Elsa
# 2014-11-07                           Big Hero 6              Hiro Hamada
# 2016-03-04                             Zootopia               Judy Hopps
# 2016-11-23                                Moana                    Moana
#
#                             villian                                song  \
# release_date_x
# 1937-12-21               Evil Queen        Some Day My Prince Will Come
# 1940-02-07                Stromboli           When You Wish upon a Star
# 1940-11-13                Chernabog                                None
# 1950-02-15            Lady Tremaine                 Bibbidi-Bobbidi-Boo
# 1951-07-28          Queen of Hearts                 The Unbirthday Song
# 1955-06-22                Si and Am                         Bella Notte
# 1959-01-29               Maleficent                   Once Upon a Dream
# 1963-12-25                Madam Mim                   Higitus Figitus\n
# 1967-10-18       Kaa and Shere Khan              The Bare Necessities\n
# 1970-12-24          Edgar Balthazar         Ev'rybody Wants to Be a Cat
# 1977-06-22            Madame Medusa                         The Journey
# 1981-07-10               Amos Slade                     Best of Friends
# 1985-07-24              Horned King                                None
# 1986-07-02        Professor Ratigan  The World's Greatest Criminal Mind
# 1988-11-18                    Sykes   Once Upon a Time in New York City
# 1989-11-17                   Ursula                       Under the Sea
# 1990-11-16      Percival C. McLeach                                  \n
# 1991-11-22                   Gaston                        Be Our Guest
# 1992-11-25                    Jafar                   A Whole New World
# 1994-06-24                     Scar                      Circle of Life
# 1995-06-23       Governor Ratcliffe                  Colors of the Wind
# 1996-06-21            Claude Frollo               God Help the Outcasts
# 1997-06-27                    Hades                     Go the Distance
# 1998-06-19                  Shan Yu        I'll Make a Man Out of You\n
# 1999-06-18                  Clayton               You'll Be in My Heart
# 2000-05-19                     Kron                                None
# 2000-12-15                     Yzma            My Funny Friend and Me\n
# 2001-06-15         Commander Rourke           Where the Dream Takes You
# 2002-06-21                     None                   He Mele No Lilo\n
# 2002-11-27              John Silver                    I'm Still Here\n
# 2003-11-01                   Denahi                Look Through My Eyes
# 2004-04-02             Alameda Slim                                None
# 2005-11-04                Foxy Loxy                                None
# 2007-03-30                    Doris                      Little Wonders
# 2008-11-21               Dr. Calico                I Thought I Lost You
# 2009-12-11             Dr. Facilier                        Almost There
# 2010-11-24            Mother Gothel                     I See the Light
# 2012-11-02                    Turbo                          Sugar Rush
# 2013-11-27              Prince Hans                         Let It Go\n
# 2014-11-07      Professor Callaghan                           Immortals
# 2016-03-04                     None                      Try Everything
# 2016-11-23                     None                   How Far I'll Go\n
#
#                release_date_y      genre MPAA_rating  total_gross  \
# release_date_x
# 1937-12-21       Dec 21, 1937    Musical           G    184925485
# 1940-02-07        Feb 9, 1940  Adventure           G     84300000
# 1940-11-13       Nov 13, 1940    Musical           G     83320000
# 1950-02-15       Feb 15, 1950      Drama           G     85000000
# 1951-07-28        Mar 5, 2010  Adventure          PG    334191110
# 1955-06-22       Jun 22, 1955      Drama           G     93600000
# 1959-01-29       Jan 29, 1959      Drama        None      9464608
# 1963-12-25       Dec 25, 1963  Adventure        None     22182353
# 1967-10-18       Oct 18, 1967    Musical   Not Rated    141843000
# 1970-12-24       Apr 24, 1970    Musical           G     55675257
# 1977-06-22       Jun 22, 1977  Adventure        None     48775599
# 1981-07-10       Jul 10, 1981     Comedy        None     43899231
# 1985-07-24       Jul 24, 1985  Adventure        None     21288692
# 1986-07-02        Jul 2, 1986  Adventure        None     23605534
# 1988-11-18       Nov 18, 1988  Adventure           G     49576671
# 1989-11-17       Nov 15, 1989  Adventure           G    111543479
# 1990-11-16       Nov 16, 1990  Adventure           G     27931461
# 1991-11-22       Nov 13, 1991    Musical           G    218951625
# 1992-11-25       Nov 11, 1992     Comedy           G    217350219
# 1994-06-24       Jun 15, 1994  Adventure           G    422780140
# 1995-06-23       Jun 10, 1995  Adventure           G    141579773
# 1996-06-21       Jun 21, 1996  Adventure           G    100138851
# 1997-06-27       Jun 13, 1997  Adventure           G     99112101
# 1998-06-19       Jun 19, 1998  Adventure           G    120620254
# 1999-06-18       Jun 16, 1999  Adventure           G    171091819
# 2000-05-19       May 19, 2000  Adventure          PG    137748063
# 2000-12-15       Dec 15, 2000  Adventure           G     89296573
# 2001-06-15        Jun 8, 2001  Adventure          PG     84052762
# 2002-06-21       Jun 21, 2002  Adventure          PG    145771527
# 2002-11-27       Nov 27, 2002  Adventure          PG     38120554
# 2003-11-01       Oct 24, 2003  Adventure           G     85336277
# 2004-04-02        Apr 2, 2004     Comedy          PG     50026353
# 2005-11-04        Nov 4, 2005  Adventure           G    135386665
# 2007-03-30       Mar 30, 2007  Adventure           G     97822171
# 2008-11-21       Nov 21, 2008     Comedy          PG    114053759
# 2009-12-11       Nov 25, 2009  Adventure           G    104400899
# 2010-11-24       Nov 24, 2010  Adventure          PG    200821936
# 2012-11-02        Nov 2, 2012  Adventure          PG    189412677
# 2013-11-27       Nov 22, 2013  Adventure          PG    400738009
# 2014-11-07        Nov 7, 2014  Adventure          PG    222527828
# 2016-03-04        Mar 4, 2016  Adventure          PG    341268248
# 2016-11-23       Nov 23, 2016  Adventure          PG    246082029
#
#                 inflation_adjusted_gross                        character  \
# release_date_x
# 1937-12-21                    5228953251                          Bashful
# 1940-02-07                    2188229052                       Blue Fairy
# 1940-11-13                    2187090808                    Ben Ali Gator
# 1950-02-15                     920608730               Anastasia Tremaine
# 1951-07-28                     357063499                            Alice
# 1955-06-22                    1236035515                 Al the Alligator
# 1959-01-29                      21505832                           Aurora
# 1963-12-25                     153870834                       Archimedes
# 1967-10-18                     789612346                            Akela
# 1970-12-24                     255161499                   Abigail Gabble
# 1977-06-22                     159743914                          Bernard
# 1981-07-10                     133118889                       Amos Slade
# 1985-07-24                      50553142                          Creeper
# 1986-07-02                      53637367                      Bartholomew
# 1988-11-18                     102254492                           DeSoto
# 1989-11-17                     223726012                           Adella
# 1990-11-16                      55796728                             Cody
# 1991-11-22                     363017667                          Armoire
# 1992-11-25                     441969178                              Abu
# 1994-06-24                     761640898                           Banzai
# 1995-06-23                     274370957                              Ben
# 1996-06-21                     190988799                         Achilles
# 1997-06-27                     182029412                          Alcmene
# 1998-06-19                     216807832                           Chi-Fu
# 1999-06-18                     283900254             Archimedes Q. Porter
# 2000-05-19                     215438985                           Aladar
# 2000-12-15                     136789252               Bucky the Squirrel
# 2001-06-15                     125188122                   Audrey Ramirez
# 2002-06-21                     211506702             Agent Wendy Pleakley
# 2002-11-27                      55189145                           B.E.N.
# 2003-11-01                     119218333                           Denahi
# 2004-04-02                      67910166                     Alameda Slim
# 2005-11-04                     177954661                     Abby Mallard
# 2007-03-30                     119860589                   Bowler Hat Guy
# 2008-11-21                     133702498                        The Agent
# 2009-12-11                     116316457                  Buford the Cook
# 2010-11-24                     214388548                      Flynn Rider
# 2012-11-02                     200354959            Adorabeezle Winterpop
# 2013-11-27                     414997174                             Anna
# 2014-11-07                     229249222                   Tadashi Hamada
# 2016-03-04                     341268248  Assistant Mayor Dawn Bellwether
# 2016-11-23                     246082029                      Gramma Tala
#
#                         voice-actor
# release_date_x
# 1937-12-21           Scotty Mattraw
# 1940-02-07           Evelyn Venable
# 1940-11-13             Jim Cummings
# 1950-02-15            Lucille Bliss
# 1951-07-28         Kathryn Beaumont
# 1955-06-22        Thurl Ravenscroft
# 1959-01-29               Mary Costa
# 1963-12-25          Junius Matthews
# 1967-10-18              John Abbott
# 1970-12-24             Monica Evans
# 1977-06-22             Bob Newheart
# 1981-07-10           Jack Albertson
# 1985-07-24           Phil Fondacaro
# 1986-07-02            Barrie Ingham
# 1988-11-18           Carl Weintraub
# 1989-11-17              Sherry Lynn
# 1990-11-16                Adam Ryen
# 1991-11-22           Jo Anne Worley
# 1992-11-25             Frank Welker
# 1994-06-24             Cheech Marin
# 1995-06-23           Billy Connolly
# 1996-06-21                     None
# 1997-06-27           Barbara Barrie
# 1998-06-19               James Hong
# 1999-06-18          Nigel Hawthorne
# 2000-05-19            D. B. Sweeney
# 2000-12-15               Bob Bergen
# 2001-06-15      Jacqueline Obradors
# 2002-06-21           Kevin McDonald
# 2002-11-27             Martin Short
# 2003-11-01              Jason Raize
# 2004-04-02              Randy Quaid
# 2005-11-04              Joan Cusack
# 2007-03-30      Stephen J. Anderson
# 2008-11-21             Greg Germann
# 2009-12-11           Michael Colyar
# 2010-11-24             Zachary Levi
# 2012-11-02                     None
# 2013-11-27             Kristen Bell
# 2014-11-07            Daniel Henney
# 2016-03-04              Jenny Slate
# 2016-11-23             Rachel House

# %%
#Problem 2 continued
#Step 3: merging decade_highest_gross and by_release_date to match film names and highest total gross for each decade

by_decade = pd.merge(decade_highest_gross, by_release_date, on = 'total_gross')
by_decade
# Out:
#    total_gross                            movie release_date_x  \
# 0    184925485  Snow White and the Seven Dwarfs     1937-12-21
# 1     84300000                        Pinocchio     1940-02-07
# 2    334191110              Alice in Wonderland     1951-07-28
# 3    141843000                  The Jungle Book     1967-10-18
# 4     55675257                   The Aristocats     1970-12-24
# 5    111543479               The Little Mermaid     1989-11-17
# 6    422780140                    The Lion King     1994-06-24
# 7    145771527                    Lilo & Stitch     2002-06-21
# 8    400738009                           Frozen     2013-11-27
#
#                  hero             villian                          song  \
# 0          Snow White          Evil Queen  Some Day My Prince Will Come
# 1           Pinocchio           Stromboli     When You Wish upon a Star
# 2               Alice     Queen of Hearts           The Unbirthday Song
# 3              Mowgli  Kaa and Shere Khan        The Bare Necessities\n
# 4  Thomas and Duchess     Edgar Balthazar   Ev'rybody Wants to Be a Cat
# 5               Ariel              Ursula                 Under the Sea
# 6               Simba                Scar                Circle of Life
# 7     Lilo and Stitch                None             He Mele No Lilo\n
# 8                Elsa         Prince Hans                   Let It Go\n
#
#   release_date_y      genre MPAA_rating  inflation_adjusted_gross  \
# 0   Dec 21, 1937    Musical           G                5228953251
# 1    Feb 9, 1940  Adventure           G                2188229052
# 2    Mar 5, 2010  Adventure          PG                 357063499
# 3   Oct 18, 1967    Musical   Not Rated                 789612346
# 4   Apr 24, 1970    Musical           G                 255161499
# 5   Nov 15, 1989  Adventure           G                 223726012
# 6   Jun 15, 1994  Adventure           G                 761640898
# 7   Jun 21, 2002  Adventure          PG                 211506702
# 8   Nov 22, 2013  Adventure          PG                 414997174
#
#               character       voice-actor
# 0               Bashful    Scotty Mattraw
# 1            Blue Fairy    Evelyn Venable
# 2                 Alice  Kathryn Beaumont
# 3                 Akela       John Abbott
# 4        Abigail Gabble      Monica Evans
# 5                Adella       Sherry Lynn
# 6                Banzai      Cheech Marin
# 7  Agent Wendy Pleakley    Kevin McDonald
# 8                  Anna      Kristen Bell

# %% [markdown]
# Provide the name of the highest-grossing film for each decade from the 1930's to the 2010's.
#
# **_____YOUR ANSWER HERE_____:**
#
# 1930s: Snow White and the Seven Dwarfs
# <HR/>
# 1940s: Pinocchio
# <HR/>
# 1950s: Alice and Wonderland
# <HR/>
# 1960s: The Jungle Book
# <HR/>
# 1970s: The Aristocats
# <HR/>
# 1980s: The Little Mermaid
# <HR/>
# 1990s: The Lion King
# <HR/>
# 2000s: Lilo and Stitch
# <HR/>
# 2010s: Frozen

# %% [markdown]
# Make sure that the value for the cell below is equal to 1. This means that each film is only counted once in the above cell. If so, then we are successfully analyzing only a single movie and not using duplicates in our analysis. We can then move forward with our values for this part of the analysis, assuming we grouped and sorted correctly.

# %%
max(by_release_date.index.value_counts())
# Out:
# 1

# %% [markdown]
# ## 3. Films with highest total gross income for each genre
#
# (20 points)

# %% [markdown]
# Our next task is to find out which film generated the highest total gross for each genre. In this dataset, we have the four following genres:
# <ol>
#     <li> Adventure </li>
#     <li> Musical </li>
#     <li> Comedy </li>
#     <li> Drama </li>
# </ol>
#
# Use the combination of 'pd.sort_values()' and 'pd.groupby()' as completed in the previous task to find these four  movies. Make sure you are only using functions available in pandas and/or numpy for your code. You should only have one single movie for each genre (i.e. a total of 4 movies). In the unlikely case of a tie, choose the older movie.
#
# **WARNING: Make sure you are using the 'disney_data' df for this section. The movie Cinderella had a 2015 reboot but does not have a different name than the original or a different ID. As such, you will need to use the entire Disney film dataset to find the highest grossing movies by genre.**

# %%
by_id.genre.value_counts()
# Out:
# Adventure    30
# Musical       5
# Comedy        4
# Drama         3
# Name: genre, dtype: int64

# %%
#Problem 3
#sorting and grouping values in disney_data to get a df with highest total gross for each genre

total_gross_all = disney_data.sort_values(['total_gross']).groupby(['genre'])['total_gross'].max()
total_gross_all
# Out:
# genre
# Adventure    422780140
# Comedy       217350219
# Drama        201151353
# Musical      218951625
# Name: total_gross, dtype: int64

# %%
#Problem 3 continued
#merging total_gross_all and disney_data to match movie names to highest total gross for each genre

by_genre = pd.merge(total_gross_all, disney_data, on = 'total_gross').groupby('genre').first()
by_genre
# Out:
#            total_gross                 movie release_date_x        hero  \
# genre
# Adventure    422780140         The Lion King     1994-06-24       Simba
# Comedy       217350219               Aladdin     1992-11-25     Aladdin
# Drama        201151353            Cinderella     1950-02-15  Cinderella
# Musical      218951625  Beauty and the Beast     1991-11-22       Belle
#
#                  villian                 song release_date_y MPAA_rating  \
# genre
# Adventure           Scar       Circle of Life   Jun 15, 1994           G
# Comedy             Jafar    A Whole New World   Nov 11, 1992           G
# Drama      Lady Tremaine  Bibbidi-Bobbidi-Boo   Mar 13, 2015          PG
# Musical           Gaston         Be Our Guest   Nov 13, 1991           G
#
#            inflation_adjusted_gross           character     voice-actor  \
# genre
# Adventure                 761640898              Banzai    Cheech Marin
# Comedy                    441969178                 Abu    Frank Welker
# Drama                     201151353  Anastasia Tremaine   Lucille Bliss
# Musical                   363017667             Armoire  Jo Anne Worley
#
#           film_id
# genre
# Adventure  882484
# Comedy     335712
# Drama      736543
# Musical    130897

# %% [markdown]
# Provide the names of the four films that generated the highest total gross income for each genre.
#
# **_____YOUR ANSWER HERE_____:**
#
# Adventure: The Lion King
# <HR/>
# Comedy: Aladdin
# <HR/>
# Drama: Cinderella
# <HR/>
# Musical: Beauty and the Beast

# %% [markdown]
# ## 4. 10 Ten Films with Adjustements for Inflation
#
# (20 points)

# %% [markdown]
# Similar to the previous section, we want to use our inflation adjusted column to find the highest grossing movies to date. You will need to sort your values by the inflation adjusted gross column and then group by movie title, selecting the first movie (i.e. .first( ) ) from your groupby object. This process will allow us to avoid any duplicates or double-counting of films. From there, you can sort by the gross one last time and use .head() to find the 10 top films. Remember, we are still using the full dataset for these remaining tasks.
#
# * Sort values by inflation adjusted gross
# * Group this sorted df by movie title to avoid double-counting
# * Use .first() to avoid double-counting films in your groupby
# * Sort your data by inflation adjusted gross and choose the top 10 films

# %%
#Problem 4

# Complete the code to for the variable
# 'top_ten_adjusted' which maintains
# the values for the top 10 films by
# highest gross adjusted for inflation.

# The variable 'sorted_films' contains
# a view of the dataset where the rows
# only contain one appearance of each film,
# eliminating duplicate appearances of films.
# However, you need to find the top 10 films 
# from this pruned list.

sorted_films = disney_data.sort_values('inflation_adjusted_gross', ascending=False).groupby('movie').first()
top_ten_adjusted = sorted_films.sort_values('inflation_adjusted_gross', ascending=False).head(10)
top_ten_adjusted
# Out:
#                                 release_date_x            hero  \
# movie
# Snow White and the Seven Dwarfs     1937-12-21      Snow White
# Pinocchio                           1940-02-07       Pinocchio
# Fantasia                            1940-11-13            None
# Lady and the Tramp                  1955-06-22  Lady and Tramp
# Cinderella                          1950-02-15      Cinderella
# The Jungle Book                     1967-10-18          Mowgli
# The Lion King                       1994-06-24           Simba
# Aladdin                             1992-11-25         Aladdin
# Frozen                              2013-11-27            Elsa
# Beauty and the Beast                1991-11-22           Belle
#
#                                             villian  \
# movie
# Snow White and the Seven Dwarfs          Evil Queen
# Pinocchio                                 Stromboli
# Fantasia                                  Chernabog
# Lady and the Tramp                        Si and Am
# Cinderella                            Lady Tremaine
# The Jungle Book                  Kaa and Shere Khan
# The Lion King                                  Scar
# Aladdin                                       Jafar
# Frozen                                  Prince Hans
# Beauty and the Beast                         Gaston
#
#                                                          song release_date_y  \
# movie
# Snow White and the Seven Dwarfs  Some Day My Prince Will Come   Dec 21, 1937
# Pinocchio                           When You Wish upon a Star    Feb 9, 1940
# Fantasia                                                 None   Nov 13, 1940
# Lady and the Tramp                                Bella Notte   Jun 22, 1955
# Cinderella                                Bibbidi-Bobbidi-Boo   Feb 15, 1950
# The Jungle Book                        The Bare Necessities\n   Oct 18, 1967
# The Lion King                                  Circle of Life   Jun 15, 1994
# Aladdin                                     A Whole New World   Nov 11, 1992
# Frozen                                            Let It Go\n   Nov 22, 2013
# Beauty and the Beast                             Be Our Guest   Nov 13, 1991
#
#                                      genre MPAA_rating  total_gross  \
# movie
# Snow White and the Seven Dwarfs    Musical           G    184925485
# Pinocchio                        Adventure           G     84300000
# Fantasia                           Musical           G     83320000
# Lady and the Tramp                   Drama           G     93600000
# Cinderella                           Drama           G     85000000
# The Jungle Book                    Musical   Not Rated    141843000
# The Lion King                    Adventure           G    422780140
# Aladdin                             Comedy           G    217350219
# Frozen                           Adventure          PG    400738009
# Beauty and the Beast               Musical           G    218951625
#
#                                  inflation_adjusted_gross  \
# movie
# Snow White and the Seven Dwarfs                5228953251
# Pinocchio                                      2188229052
# Fantasia                                       2187090808
# Lady and the Tramp                             1236035515
# Cinderella                                      920608730
# The Jungle Book                                 789612346
# The Lion King                                   761640898
# Aladdin                                         441969178
# Frozen                                          414997174
# Beauty and the Beast                            363017667
#
#                                                  character  \
# movie
# Snow White and the Seven Dwarfs                    Bashful
# Pinocchio                        J. Worthington Foulfellow
# Fantasia                                         Chernabog
# Lady and the Tramp                                  Beaver
# Cinderella                                 Major the Horse
# The Jungle Book                                 King Louie
# The Lion King                                           Ed
# Aladdin                                            Aladdin
# Frozen                                                Anna
# Beauty and the Beast                  Sultan the Footstool
#
#                                               voice-actor film_id
# movie
# Snow White and the Seven Dwarfs            Scotty Mattraw  482267
# Pinocchio                                  Walter Catlett  484637
# Fantasia                                     Corey Burton  149036
# Lady and the Tramp                           Stan Freberg  821764
# Cinderella                                           None  736543
# The Jungle Book                               Louis Prima  576980
# The Lion King                                Jim Cummings  882484
# Aladdin                          Scott Weinger; Brad Kane  335712
# Frozen                                       Kristen Bell  550486
# Beauty and the Beast                         Frank Welker  130897

# %%
#Problem 4 continued: printing list of 10 movies with highest inflation adjusted gross

print(top_ten_adjusted['inflation_adjusted_gross'])
# Out:
# movie
# Snow White and the Seven Dwarfs    5228953251
# Pinocchio                          2188229052
# Fantasia                           2187090808
# Lady and the Tramp                 1236035515
# Cinderella                          920608730
# The Jungle Book                     789612346
# The Lion King                       761640898
# Aladdin                             441969178
# Frozen                              414997174
# Beauty and the Beast                363017667
# Name: inflation_adjusted_gross, dtype: int64

# %% [markdown]
# Provide the names of the 10 highest-grossing films (adjusted for inflation) from The Walt Disney Studios catalog.
#
# **_____YOUR ANSWER HERE_____:**
#
# Snow White and the Seven Dwarfs
# <HR/>
# Pinocchio
# <HR/>
# Fantasia
# <HR/>
# Lady and the Tramp
# <HR/>
# Cinderella
# <HR/>
# The Jungle Book
# <HR/>
# The Lion King
# <HR/>
# Aladdin
# <HR/>
# Frozen
# <HR/>
# Beauty and the Beast

# %% [markdown]
# ## 5. Voice actors for each of the top movies from Task 4
#
# (20 points)

# %% [markdown]
# From the top ten films in the previous section, create a dictionary of pairs where the key is the name of the film and the value is the list of voice actors that starred in that film.
#
# Example format:
#
# * {  film : voice actors}
#
# Part of this code has already been written for you. It will be your task to get the data into a dictionary format.

# %%
#Problem 5: creating a for loop that will create a dictionary containing pairs of films and their voice actors
  # TO DO:
    # Complete the code by implementing
    # the rest of this for loop. Your
    # 'voice_actors' should be a list
    # of dictionaries contain the film
    # as a key and a list of voice actors
    # as a value.
    # You set an item in a dictionary by doing dictionary[key] = item
    
voice_actors = []

film_voice_actors = {}

for film in top_ten_adjusted.index:
    voice_actors = (disney_data[disney_data['movie'] == film]['voice-actor'].to_list())
    film_voice_actors[film] = voice_actors

# %%
film_voice_actors
# Out:
# {'Snow White and the Seven Dwarfs': ['Scotty Mattraw',
#   'Roy Atwell',
#   'Eddie Collins',
#   'Pinto Colvig',
#   'Otis Harlan',
#   'Stuart Buchanan',
#   'Moroni Olsen',
#   'Harry Stockwell',
#   'Lucille La Verne',
#   'Pinto Colvig',
#   'Billy Gilbert',
#   'Adriana Caselotti'],
#  'Pinocchio': ['Evelyn Venable',
#   'None',
#   'Charles Judels',
#   'Mel Blanc',
#   'Christian Rub',
#   'Mel Blanc',
#   'Walter Catlett',
#   'Cliff Edwards; Eddie Carroll',
#   'Frankie Darro',
#   'Thurl Ravenscroft',
#   'Dickie Jones',
#   'Charles Judels'],
#  'Fantasia': ['Jim Cummings',
#   'Corey Burton',
#   'Tress MacNeille',
#   'Tress MacNeille',
#   'None',
#   'Corey Burton'],
#  'Lady and the Tramp': ['Thurl Ravenscroft',
#   'Verna Felton',
#   'Stan Freberg',
#   'Peggy Lee',
#   'Lee Millar',
#   'Bill Thompson',
#   'Barbara Luddy',
#   'Peggy Lee',
#   'Peggy Lee',
#   'Larry Roberts',
#   'Bill Baucom'],
#  'Cinderella': ['Lucille Bliss',
#   'Jimmy MacDonald; Frank Welker',
#   'Ilene Woods',
#   'Don Barclay',
#   'Rhoda Williams; Russi Taylor',
#   'Verna Felton; Russi Taylor',
#   'Larry Grey',
#   'Luis Van Rooten; Rob Paulsen',
#   'Jimmy MacDonald; Corey Burton',
#   'Jimmy MacDonald; Rob Paulsen',
#   'Luis Van Rooten',
#   'Eleanor Audley; Susanne Blakeslee',
#   'June Foray',
#   'None',
#   'William Phipps',
#   'Lucille Bliss',
#   'Jimmy MacDonald; Frank Welker',
#   'Ilene Woods',
#   'Don Barclay',
#   'Rhoda Williams; Russi Taylor',
#   'Verna Felton; Russi Taylor',
#   'Larry Grey',
#   'Luis Van Rooten; Rob Paulsen',
#   'Jimmy MacDonald; Corey Burton',
#   'Jimmy MacDonald; Rob Paulsen',
#   'Luis Van Rooten',
#   'Eleanor Audley; Susanne Blakeslee',
#   'June Foray',
#   'None',
#   'William Phipps'],
#  'The Jungle Book': ['John Abbott',
#   'Sebastian Cabot',
#   'Phil Harris',
#   "J. Pat O'Malley",
#   "J. Pat O'Malley",
#   'Lord Tim Hudson',
#   'Ben Wright',
#   'Chad Stuart',
#   'Leo De Lyon',
#   'Clint Howard',
#   'Sterling Holloway; Jim Cummings',
#   'Louis Prima',
#   'Bruce Reitherman',
#   'Darleen Carr',
#   'George Sanders',
#   'Verna Felton',
#   'Digby Wolfe',
#   'John Abbott',
#   'Sebastian Cabot',
#   'Phil Harris',
#   "J. Pat O'Malley",
#   "J. Pat O'Malley",
#   'Lord Tim Hudson',
#   'Ben Wright',
#   'Chad Stuart',
#   'Leo De Lyon',
#   'Clint Howard',
#   'Sterling Holloway; Jim Cummings',
#   'Louis Prima',
#   'Bruce Reitherman',
#   'Darleen Carr',
#   'George Sanders',
#   'Verna Felton',
#   'Digby Wolfe',
#   'John Abbott',
#   'Sebastian Cabot',
#   'Phil Harris',
#   "J. Pat O'Malley",
#   "J. Pat O'Malley",
#   'Lord Tim Hudson',
#   'Ben Wright',
#   'Chad Stuart',
#   'Leo De Lyon',
#   'Clint Howard',
#   'Sterling Holloway; Jim Cummings',
#   'Louis Prima',
#   'Bruce Reitherman',
#   'Darleen Carr',
#   'George Sanders',
#   'Verna Felton',
#   'Digby Wolfe'],
#  'The Lion King': ['Cheech Marin',
#   'Jim Cummings',
#   'James Earl Jones',
#   'Moira Kelly; Niketa Calame',
#   'Ernie Sabella',
#   'Robert Guillaume',
#   'Madge Sinclair',
#   'Zoe Leader',
#   'Jeremy Irons',
#   'Whoopi Goldberg',
#   'Jonathan Taylor Thomas',
#   'Matthew Broderick',
#   'Nathan Lane',
#   'Rowan Atkinson'],
#  'Aladdin': ['Frank Welker',
#   'Scott Weinger; Brad Kane',
#   'Robin Williams',
#   'James Avery',
#   'Gilbert Gottfried',
#   'Jonathan Freeman',
#   'None',
#   'Charlie Adler',
#   'Jonathan Brandis',
#   'Linda Larkin; Lea Salonga',
#   'Frank Welker',
#   'Jim Cummings',
#   'Kellie Martin',
#   'Douglas Seale'],
#  'Frozen': ['Kristen Bell',
#   'Alan Tudyk',
#   'Idina Menzel',
#   'Jonathan Groff',
#   'Chris Williams',
#   'Josh Gad',
#   'Santino Fontana',
#   'None'],
#  'Beauty and the Beast': ['Jo Anne Worley',
#   'Mary Kay Bergman',
#   'Alex Murphey',
#   'Robby Benson',
#   "Paige O'Hara",
#   'Kath Soucie',
#   'Alvin Epstein',
#   'Brian Cummings',
#   'Bradley Michael Pierce',
#   'David Ogden Stiers',
#   'Kimmy Robertson',
#   'Richard White',
#   'Jesse Corti',
#   'Jerry Orbach',
#   'Rex Everhart',
#   'Tony Jay',
#   'Angela Lansbury',
#   'Hal Smith',
#   'Frank Welker']}
